# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Std_eve\Desktop\models\KNN\KNN\Heart Failure Prediction Files\heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
#Encodeing categerical value in numerical value

cat_col=['Sex', 'ChestPainType', 
       'RestingECG',  'ExerciseAngina',  'ST_Slope',
       ]
for i in cat_col:
    print(i,df[i].unique())
# Out:
# Sex ['M' 'F']
# ChestPainType ['ATA' 'NAP' 'ASY' 'TA']
# RestingECG ['Normal' 'ST' 'LVH']
# ExerciseAngina ['N' 'Y']
# ST_Slope ['Up' 'Flat' 'Down']

# %%
newdf=pd.get_dummies(df,drop_first=True) #convert to numerical

# %%
newdf=newdf.astype(int)

# %%
newdf
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172        0             0
# 1     49        160          180          0    156        1             1
# 2     37        130          283          0     98        0             0
# 3     48        138          214          0    108        1             1
# 4     54        150          195          0    122        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132        1             1
# 914   68        144          193          1    141        3             1
# 915   57        130          131          0    115        1             1
# 916   57        130          236          0    174        0             1
# 917   38        138          175          0    173        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
sns.pairplot(newdf)

# %%
#inistalize features and target x,y

X=newdf.drop(columns=['HeartDisease'])
y=newdf['HeartDisease']

# %%
#standardase

from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
xcolumns=X.columns

# %%
X=scaler.fit_transform(X)

# %%
X=pd.DataFrame(X,columns=xcolumns)

# %%
X.head()
# Out:
#         Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak     Sex_M  \
# 0 -1.433140   0.410909     0.825070  -0.551341  1.382928 -0.727592  0.515952
# 1 -0.478484   1.491752    -0.171961  -0.551341  0.754157  0.282891 -1.938163
# 2 -1.751359  -0.129513     0.770188  -0.551341 -1.525138 -0.727592  0.515952
# 3 -0.584556   0.302825     0.139040  -0.551341 -1.132156  0.282891 -1.938163
# 4  0.051881   0.951331    -0.034755  -0.551341 -0.581981 -0.727592  0.515952
#
#    ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  RestingECG_Normal  \
# 0           2.075177          -0.532838         -0.229679           0.814275
# 1          -0.481887           1.876744         -0.229679           0.814275
# 2           2.075177          -0.532838         -0.229679          -1.228087
# 3          -0.481887          -0.532838         -0.229679           0.814275
# 4          -0.481887           1.876744         -0.229679           0.814275
#
# ...

# %%
#split data tarin test split


from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=100)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=1)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
y_pre=model.predict(X_test)

# %%
from sklearn import metrics

# %%
metrics.confusion_matrix(y_test,y_pre)
# Out:
# array([[ 94,  28],
#        [ 27, 127]])

# %%
print(metrics.classification_report(y_test,y_pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77       122
#            1       0.82      0.82      0.82       154
#
#     accuracy                           0.80       276
#    macro avg       0.80      0.80      0.80       276
# weighted avg       0.80      0.80      0.80       276

# %%
error_rate=[]
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train,y_train)
    pred_i=knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
sns.scatterplot(x = range(1,40), y = error_rate)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=1')
print('\n')
print(metrics.classification_report(y_test,pred))
sns.heatmap(metrics.confusion_matrix(y_test,y_pre), annot = True, fmt = 'd')
plt.show()

print('r2 score of our model is :', metrics.r2_score(pred, y_test))
# Out:
# WITH K=1
#
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77       122
#            1       0.82      0.82      0.82       154
#
#     accuracy                           0.80       276
#    macro avg       0.80      0.80      0.80       276
# weighted avg       0.80      0.80      0.80       276
# r2 score of our model is : 0.19061583577712593
